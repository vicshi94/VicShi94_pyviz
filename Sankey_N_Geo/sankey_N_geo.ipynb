# %%
import json

from pyecharts import options as opts
from pyecharts.charts import Sankey

with open("subject.json", "r", encoding="utf-8") as f:
    j = json.load(f)
c = (
    Sankey()
    .add(
        "Frequency",
        nodes=j["nodes"],
        links=j["links"],
        pos_top="10%",
        layout_iterations = 64,
        focus_node_mode="adjacency",
        levels=[
            opts.SankeyLevelsOpts(
                depth=0,
                itemstyle_opts=opts.ItemStyleOpts(color="#fbb4ae"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=1,
                itemstyle_opts=opts.ItemStyleOpts(color="#b3cde3"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=2,
                itemstyle_opts=opts.ItemStyleOpts(color="#ccebc5"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
        ],
        linestyle_opt=opts.LineStyleOpts(curve=0.5),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Multidisciplinary in Citation Network"),
        tooltip_opts=opts.TooltipOpts(trigger="item", trigger_on="mousemove"),
    )
    # .render("subject_citation.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ceb72124ad054c81b82759bd27aa91f3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ceb72124ad054c81b82759bd27aa91f3 = echarts.init(
#                     document.getElementById('ceb72124ad054c81b82759bd27aa91f3'), 'white', {renderer: 'canvas'});
#                 var option_ceb72124ad054c81b82759bd27aa91f3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "Frequency",
#             "data": [
#                 {
#                     "name": "PSYCHIATRY"
#                 },
#                 {
#                     "name": "INTERDISCIPLINARY"
#                 },
#                 {
#                     "name": "HUMANITIES"
#                 },
#                 {
#                     "name": "COMPUTER_SCIENCE"
#                 },
#                 {
#                     "name": "Total"
#                 },
#                 {
#                     "name": "Department of Interactive Media"
#                 },
#                 {
#                     "name": "Department of Communication Studies"
#                 },
#                 {
#                     "name": "Academy of Film"
#                 },
#                 {
#                     "name": "LAW"
#                 },
#                 {
#                     "name": "COMMUNICATION"
#                 },
#                 {
#                     "name": "SPORTS"
#                 },
#                 {
#                     "name": "MEDICINE"
#                 },
#                 {
#                     "name": "URBAN"
#                 },
#                 {
#                     "name": "BIOLOGY"
#                 },
#                 {
#                     "name": "INFORMATION"
#                 },
#                 {
#                     "name": "SOCIOLOGY"
#                 },
#                 {
#                     "name": "PSYCHOLOGY"
#                 },
#                 {
#                     "name": "BUSINESS"
#                 },
#                 {
#                     "name": "PHYSICS"
#                 },
#                 {
#                     "name": "POLITICS"
#                 },
#                 {
#                     "name": "NEUROSCIENCE"
#                 },
#                 {
#                     "name": "Department of Journalism"
#                 },
#                 {
#                     "name": "GEOGRAPHY"
#                 },
#                 {
#                     "name": "LINGUISITIC"
#                 },
#                 {
#                     "name": "MANAGEMENT"
#                 },
#                 {
#                     "name": "ENVIRONMENT"
#                 },
#                 {
#                     "name": "NURSING"
#                 },
#                 {
#                     "name": "MATHEMATICS"
#                 },
#                 {
#                     "name": "EDUCATION"
#                 },
#                 {
#                     "name": "ART"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Interactive Media",
#                     "value": 262
#                 },
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Communication Studies",
#                     "value": 184
#                 },
#                 {
#                     "source": "MEDICINE",
#                     "target": "Department of Interactive Media",
#                     "value": 111
#                 },
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Journalism",
#                     "value": 93
#                 },
#                 {
#                     "source": "BUSINESS",
#                     "target": "Department of Communication Studies",
#                     "value": 79
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Department of Interactive Media",
#                     "value": 74
#                 },
#                 {
#                     "source": "MANAGEMENT",
#                     "target": "Department of Interactive Media",
#                     "value": 72
#                 },
#                 {
#                     "source": "BUSINESS",
#                     "target": "Department of Interactive Media",
#                     "value": 68
#                 },
#                 {
#                     "source": "MANAGEMENT",
#                     "target": "Department of Communication Studies",
#                     "value": 68
#                 },
#                 {
#                     "source": "MEDICINE",
#                     "target": "Department of Communication Studies",
#                     "value": 52
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Department of Communication Studies",
#                     "value": 51
#                 },
#                 {
#                     "source": "BUSINESS",
#                     "target": "Department of Journalism",
#                     "value": 32
#                 },
#                 {
#                     "source": "PSYCHOLOGY",
#                     "target": "Department of Interactive Media",
#                     "value": 30
#                 },
#                 {
#                     "source": "PSYCHOLOGY",
#                     "target": "Department of Communication Studies",
#                     "value": 28
#                 },
#                 {
#                     "source": "PHYSICS",
#                     "target": "Department of Interactive Media",
#                     "value": 27
#                 },
#                 {
#                     "source": "SOCIOLOGY",
#                     "target": "Department of Interactive Media",
#                     "value": 26
#                 },
#                 {
#                     "source": "MANAGEMENT",
#                     "target": "Department of Journalism",
#                     "value": 23
#                 },
#                 {
#                     "source": "PSYCHIATRY",
#                     "target": "Department of Interactive Media",
#                     "value": 23
#                 },
#                 {
#                     "source": "COMPUTER_SCIENCE",
#                     "target": "Department of Interactive Media",
#                     "value": 21
#                 },
#                 {
#                     "source": "NURSING",
#                     "target": "Department of Interactive Media",
#                     "value": 20
#                 },
#                 {
#                     "source": "EDUCATION",
#                     "target": "Department of Interactive Media",
#                     "value": 20
#                 },
#                 {
#                     "source": "POLITICS",
#                     "target": "Department of Communication Studies",
#                     "value": 20
#                 },
#                 {
#                     "source": "NURSING",
#                     "target": "Department of Communication Studies",
#                     "value": 19
#                 },
#                 {
#                     "source": "PHYSICS",
#                     "target": "Department of Communication Studies",
#                     "value": 19
#                 },
#                 {
#                     "source": "EDUCATION",
#                     "target": "Department of Communication Studies",
#                     "value":

# %%
with open("colaboration.json", "r", encoding="utf-8") as f:
    j = json.load(f)
c = (
    Sankey()
    .add(
        "Frequency",
        nodes=j["nodes"],
        links=j["links"],
        pos_top="10%",
        layout_iterations = 64,
        focus_node_mode="adjacency",
        levels=[
            opts.SankeyLevelsOpts(
                depth=0,
                itemstyle_opts=opts.ItemStyleOpts(color="#fbb4ae"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=1,
                itemstyle_opts=opts.ItemStyleOpts(color="#b3cde3"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
            opts.SankeyLevelsOpts(
                depth=2,
                itemstyle_opts=opts.ItemStyleOpts(color="#ccebc5"),
                linestyle_opts=opts.LineStyleOpts(color="source", opacity=0.6),
            ),
        ],
        linestyle_opt=opts.LineStyleOpts(curve=0.5),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Multidisciplinary in Cooperation Network"),
        tooltip_opts=opts.TooltipOpts(trigger="item", trigger_on="mousemove"),
    )
    # .render("subject_colaboration.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="484498e24dfc4a6283f418bfb8b40aef" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_484498e24dfc4a6283f418bfb8b40aef = echarts.init(
#                     document.getElementById('484498e24dfc4a6283f418bfb8b40aef'), 'white', {renderer: 'canvas'});
#                 var option_484498e24dfc4a6283f418bfb8b40aef = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "Frequency",
#             "data": [
#                 {
#                     "name": "POLITICS"
#                 },
#                 {
#                     "name": "Academy of Film"
#                 },
#                 {
#                     "name": "LAW"
#                 },
#                 {
#                     "name": "Department of Journalism"
#                 },
#                 {
#                     "name": "COMMUNICATION"
#                 },
#                 {
#                     "name": "MANAGEMENT"
#                 },
#                 {
#                     "name": "MEDICINE"
#                 },
#                 {
#                     "name": "COMPUTER_SCIENCE"
#                 },
#                 {
#                     "name": "URBAN"
#                 },
#                 {
#                     "name": "Total"
#                 },
#                 {
#                     "name": "SOCIOLOGY"
#                 },
#                 {
#                     "name": "Department of Interactive Media"
#                 },
#                 {
#                     "name": "Department of Communication Studies"
#                 },
#                 {
#                     "name": "MATHEMATICS"
#                 },
#                 {
#                     "name": "BUSINESS"
#                 },
#                 {
#                     "name": "EDUCATION"
#                 },
#                 {
#                     "name": "ART"
#                 },
#                 {
#                     "name": "PHYSICS"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Interactive Media",
#                     "value": 42
#                 },
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Communication Studies",
#                     "value": 33
#                 },
#                 {
#                     "source": "COMMUNICATION",
#                     "target": "Department of Journalism",
#                     "value": 15
#                 },
#                 {
#                     "source": "MEDICINE",
#                     "target": "Department of Communication Studies",
#                     "value": 9
#                 },
#                 {
#                     "source": "COMPUTER_SCIENCE",
#                     "target": "Department of Interactive Media",
#                     "value": 4
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Department of Communication Studies",
#                     "value": 4
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Academy of Film",
#                     "value": 3
#                 },
#                 {
#                     "source": "URBAN",
#                     "target": "Department of Interactive Media",
#                     "value": 3
#                 },
#                 {
#                     "source": "SOCIOLOGY",
#                     "target": "Department of Journalism",
#                     "value": 3
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Department of Interactive Media",
#                     "value": 3
#                 },
#                 {
#                     "source": "BUSINESS",
#                     "target": "Department of Communication Studies",
#                     "value": 2
#                 },
#                 {
#                     "source": "PHYSICS",
#                     "target": "Department of Interactive Media",
#                     "value": 1
#                 },
#                 {
#                     "source": "POLITICS",
#                     "target": "Department of Interactive Media",
#                     "value": 1
#                 },
#                 {
#                     "source": "MANAGEMENT",
#                     "target": "Department of Communication Studies",
#                     "value": 1
#                 },
#                 {
#                     "source": "ART",
#                     "target": "Department of Journalism",
#                     "value": 1
#                 },
#                 {
#                     "source": "EDUCATION",
#                     "target": "Department of Journalism",
#                     "value": 1
#                 },
#                 {
#                     "source": "MATHEMATICS",
#                     "target": "Department of Journalism",
#                     "value": 1
#                 },
#                 {
#                     "source": "LAW",
#                     "target": "Department of Interactive Media",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "COMMUNICATION",
#                     "value": 90
#                 },
#                 {
#                     "source": "Total",
#                     "target": "ART",
#                     "value": 11
#                 },
#                 {
#                     "source": "Total",
#                     "target": "MEDICINE",
#                     "value": 9
#                 },
#                 {
#                     "source": "Total",
#                     "target": "COMPUTER_SCIENCE",
#                     "value": 4
#                 },
#                 {
#                     "source": "Total",
#                     "target": "URBAN",
#                     "value": 3
#                 },
#                 {
#                     "source": "Total",
#                     "target": "SOCIOLOGY",
#                     "value": 3
#                 },
#                 {
#                     "source": "Total",
#                     "target": "BUSINESS",
#                     "value": 2
#                 },
#                 {
#                     "source": "Total",
#                     "target": "PHYSICS",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "POLITICS",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "LAW",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "MANAGEMENT",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "EDUCATION",
#                     "value": 1
#                 },
#                 {
#                     "source": "Total",
#                     "target": "MATHEMATICS",
#                     "value": 1
#                 }
#             ],
#             "left": "5%",
#             "top": "10%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "layoutIteration": 64,
#             "orient": "horizontal",

# %%
with open("country.json", "r", encoding="utf-8") as f:
    j = json.load(f)
    citation_region = j['citation']
    colaboration_region = j['cooperation']

# %%
# change dict to list [(key, value)]
citation_region = list(citation_region.items())
colaboration_region = list(colaboration_region.items())

# %%
from geopy.geocoders import Nominatim
geo_json = dict()
geolocator = Nominatim(user_agent="my_app")
# Specify the location you want to convert
for p in citation_region:
    # Use geocode method to get the location's coordinates
    try:
        location_data = geolocator.geocode(p[0],country_codes= p[0])
        # Extract the latitude and longitude from the location data
        latitude = location_data.latitude
        longitude = location_data.longitude
    except:
        location_data = geolocator.geocode(p[0])
        # Extract the latitude and longitude from the location data
        latitude = location_data.latitude
        longitude = location_data.longitude
    geo_json[p[0]] = [longitude,latitude]

# %%
geo_json['CN'] = [116.4074, 39.9042] #Beijing
with open('geo.json', 'w') as f:
    json.dump(geo_json, f)

# %%
pair_citation_region = [(x[0], 'HK') for x in citation_region]
pair_colaboration_region = [('HK',x[0]) for x in colaboration_region]

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_coordinate_json(json_file="geo.json")
    .add_schema(
        maptype="world",
        itemstyle_opts=opts.ItemStyleOpts(color="#f0f0f0", border_color="#111"),
        min_scale_limit=1,
        max_scale_limit=10,
    )
    .add(
        "geo",
        citation_region,
        type_=ChartType.HEATMAP,
    )
    .add(
        "geo",
        pair_citation_region,
        type_=ChartType.LINES,
        is_large=True,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=1, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Citation Network")
    )
    # .render("Citation_geo_heatmap.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="dfea25ddf319440da6f393fd3addcf7b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_dfea25ddf319440da6f393fd3addcf7b = echarts.init(
#                     document.getElementById('dfea25ddf319440da6f393fd3addcf7b'), 'white', {renderer: 'canvas'});
#                 var option_dfea25ddf319440da6f393fd3addcf7b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "CN",
#                     "value": [
#                         116.4074,
#                         39.9042,
#                         554
#                     ]
#                 },
#                 {
#                     "name": "US",
#                     "value": [
#                         -100.445882,
#                         39.7837304,
#                         461
#                     ]
#                 },
#                 {
#                     "name": "GB",
#                     "value": [
#                         -3.2765753,
#                         54.7023545,
#                         99
#                     ]
#                 },
#                 {
#                     "name": "IN",
#                     "value": [
#                         78.6677428,
#                         22.3511148,
#                         62
#                     ]
#                 },
#                 {
#                     "name": "DE",
#                     "value": [
#                         10.4478313,
#                         51.1638175,
#                         57
#                     ]
#                 },
#                 {
#                     "name": "AU",
#                     "value": [
#                         134.755,
#                         -24.7761086,
#                         57
#                     ]
#                 },
#                 {
#                     "name": "IT",
#                     "value": [
#                         12.674297,
#                         42.6384261,
#                         42
#                     ]
#                 },
#                 {
#                     "name": "SG",
#                     "value": [
#                         103.8194992,
#                         1.357107,
#                         39
#                     ]
#                 },
#                 {
#                     "name": "ES",
#                     "value": [
#                         -4.8379791,
#                         39.3260685,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "KR",
#                     "value": [
#                         127.6961188,
#                         36.638392,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "TW",
#                     "value": [
#                         120.9820179,
#                         23.9739374,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "ID",
#                     "value": [
#                         117.8902853,
#                         -2.4833826,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "HK",
#                     "value": [
#                         114.1849161,
#                         22.350627,
#                         29
#                     ]
#                 },
#                 {
#                     "name": "IL",
#                     "value": [
#                         34.8594762,
#                         30.8124247,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "PT",
#                     "value": [
#                         -8.1353519,
#                         39.6621648,
#                         25
#                     ]
#                 },
#                 {
#                     "name": "JP",
#                     "value": [
#                         139.2394179,
#                         36.5748441,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "RU",
#                     "value": [
#                         97.7453061,
#                         64.6863136,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "RO",
#                     "value": [
#                         24.6859225,
#                         45.9852129,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "CA",
#                     "value": [
#                         -107.991707,
#                         61.0666922,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "BE",
#                     "value": [
#                         4.6667145,
#                         50.6402809,
#                         17
#                     ]
#                 },
#                 {
#                     "name": "PK",
#                     "value": [
#                         71.247499,
#                         30.3308401,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "FR",
#                     "value": [
#                         1.8883335,
#                         46.603354,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "GR",
#                     "value": [
#                         21.9877132,
#                         38.9953683,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "PL",
#                     "value": [
#                         19.134422,
#                         52.215933,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "NG",
#                     "value": [
#                         7.9999721,
#                         9.6000359,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "MY",
#                     "value": [
#                         102.2656823,
#                         4.5693754,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "CL",
#                     "value": [
#                         -71.3187697,
#                         -31.7613365,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "FI",
#                     "value": [
#                         25.9209164,
#                         63.2467777,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "IE",
#                     "value": [
#                         -7.9794599,
#                         52.865196,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "BR",
#                     "value": [
#                         -40.4808697,
#                         -9.4690789,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "NO",

# %%
c = (
    Geo()
    .add_coordinate_json(json_file="geo.json")
    .add_schema(
        maptype="world",
        itemstyle_opts=opts.ItemStyleOpts(color="#f0f0f0", border_color="#111"),
        min_scale_limit=1,
        max_scale_limit=10,
    )
    .add(
        "geo",
        citation_region,
        type_=ChartType.EFFECT_SCATTER,
        color="white"
    )
    .add(
        "geo",
        pair_citation_region,
        type_=ChartType.LINES,
        is_large=True,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=2, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Citation Network")
    )
    # .render("Citation_geo_scatter.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="df76ba04e59349668f43e4ae4a20b391" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_df76ba04e59349668f43e4ae4a20b391 = echarts.init(
#                     document.getElementById('df76ba04e59349668f43e4ae4a20b391'), 'white', {renderer: 'canvas'});
#                 var option_df76ba04e59349668f43e4ae4a20b391 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "white",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "CN",
#                     "value": [
#                         116.4074,
#                         39.9042,
#                         554
#                     ]
#                 },
#                 {
#                     "name": "US",
#                     "value": [
#                         -100.445882,
#                         39.7837304,
#                         461
#                     ]
#                 },
#                 {
#                     "name": "GB",
#                     "value": [
#                         -3.2765753,
#                         54.7023545,
#                         99
#                     ]
#                 },
#                 {
#                     "name": "IN",
#                     "value": [
#                         78.6677428,
#                         22.3511148,
#                         62
#                     ]
#                 },
#                 {
#                     "name": "DE",
#                     "value": [
#                         10.4478313,
#                         51.1638175,
#                         57
#                     ]
#                 },
#                 {
#                     "name": "AU",
#                     "value": [
#                         134.755,
#                         -24.7761086,
#                         57
#                     ]
#                 },
#                 {
#                     "name": "IT",
#                     "value": [
#                         12.674297,
#                         42.6384261,
#                         42
#                     ]
#                 },
#                 {
#                     "name": "SG",
#                     "value": [
#                         103.8194992,
#                         1.357107,
#                         39
#                     ]
#                 },
#                 {
#                     "name": "ES",
#                     "value": [
#                         -4.8379791,
#                         39.3260685,
#                         37
#                     ]
#                 },
#                 {
#                     "name": "KR",
#                     "value": [
#                         127.6961188,
#                         36.638392,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "TW",
#                     "value": [
#                         120.9820179,
#                         23.9739374,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "ID",
#                     "value": [
#                         117.8902853,
#                         -2.4833826,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "HK",
#                     "value": [
#                         114.1849161,
#                         22.350627,
#                         29
#                     ]
#                 },
#                 {
#                     "name": "IL",
#                     "value": [
#                         34.8594762,
#                         30.8124247,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "PT",
#                     "value": [
#                         -8.1353519,
#                         39.6621648,
#                         25
#                     ]
#                 },
#                 {
#                     "name": "JP",
#                     "value": [
#                         139.2394179,
#                         36.5748441,
#                         24
#                     ]
#                 },
#                 {
#                     "name": "RU",
#                     "value": [
#                         97.7453061,
#                         64.6863136,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "RO",
#                     "value": [
#                         24.6859225,
#                         45.9852129,
#                         21
#                     ]
#                 },
#                 {
#                     "name": "CA",
#                     "value": [
#                         -107.991707,
#                         61.0666922,
#                         20
#                     ]
#                 },
#                 {
#                     "name": "BE",
#                     "value": [
#                         4.6667145,
#                         50.6402809,
#                         17
#                     ]
#                 },
#                 {
#                     "name": "PK",
#                     "value": [
#                         71.247499,
#                         30.3308401,
#                         16
#                     ]
#                 },
#                 {
#                     "name": "FR",
#                     "value": [
#                         1.8883335,
#                         46.603354,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "GR",
#                     "value": [
#                         21.9877132,
#                         38.9953683,
#                         15
#                     ]
#                 },
#                 {
#                     "name": "PL",
#                     "value": [
#                         19.134422,
#                         52.215933,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "NG",
#                     "value": [
#                         7.9999721,
#                         9.6000359,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "MY",
#                     "value": [
#                         102.2656823,
#                         4.5693754,
#                         14
#                     ]
#                 },
#                 {
#                     "name": "CL",
#                     "value": [
#                         -71.3187697,
#                         -31.7613365,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "FI",
#                     "value": [
#                         25.9209164,
#                         63.2467777,
#                         13
#                     ]
#                 },
#                 {
#                     "name": "IE",
#                     "value": [
#                         -7.9794599,
#                         52.865196,
#                         13
#                     ]
#                 },

# %%
c = (
    Geo()
    .add_coordinate_json(json_file="geo.json")
    .add_schema(
        maptype="world",
        itemstyle_opts=opts.ItemStyleOpts(color="#f0f0f0", border_color="#111"),
        min_scale_limit=1,
        max_scale_limit=10,
    )
    .add(
        "geo",
        colaboration_region,
        type_=ChartType.HEATMAP,
    )
    .add(
        "geo",
        pair_colaboration_region,
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=3, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Cooperation Network")
    )
    # .render("Cooperation_geo_heatmap.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="c1d70eafa96a401faad220ef0e0af0ed" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_c1d70eafa96a401faad220ef0e0af0ed = echarts.init(
#                     document.getElementById('c1d70eafa96a401faad220ef0e0af0ed'), 'white', {renderer: 'canvas'});
#                 var option_c1d70eafa96a401faad220ef0e0af0ed = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "CN",
#                     "value": [
#                         116.4074,
#                         39.9042,
#                         97
#                     ]
#                 },
#                 {
#                     "name": "US",
#                     "value": [
#                         -100.445882,
#                         39.7837304,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "HK",
#                     "value": [
#                         114.1849161,
#                         22.350627,
#                         7
#                     ]
#                 },
#                 {
#                     "name": "GB",
#                     "value": [
#                         -3.2765753,
#                         54.7023545,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "SG",
#                     "value": [
#                         103.8194992,
#                         1.357107,
#                         4
#                     ]
#                 },
#                 {
#                     "name": "NL",
#                     "value": [
#                         4.7599085,
#                         52.3104607,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "MY",
#                     "value": [
#                         102.2656823,
#                         4.5693754,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "AT",
#                     "value": [
#                         14.12456,
#                         47.59397,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "CA",
#                     "value": [
#                         -107.991707,
#                         61.0666922,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "PK",
#                     "value": [
#                         71.247499,
#                         30.3308401,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "JP",
#                     "value": [
#                         139.2394179,
#                         36.5748441,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "BR",
#                     "value": [
#                         -40.4808697,
#                         -9.4690789,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "AU",
#                     "value": [
#                         134.755,
#                         -24.7761086,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "PT",
#                     "value": [
#                         -8.1353519,
#                         39.6621648,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "MO",
#                     "value": [
#                         10.935960870530739,
#                         44.5384728,
#                         1
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 3
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "HK->CN",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             116.4074,
#                             39.9042
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->US",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             -100.445882,
#                             39.7837304
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->HK",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             114.1849161,
#                             22.350627
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->GB",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             -3.2765753,
#                             54.7023545
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->SG",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             103.8194992,
#                             1.357107
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->NL",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             4.7599085,
#                             52.3104607
#                         ]
#                     ]
#                 },

# %%
c = (
    Geo()
    .add_coordinate_json(json_file="geo.json")
    .add_schema(
        maptype="world",
        itemstyle_opts=opts.ItemStyleOpts(color="#f0f0f0", border_color="#111"),
        min_scale_limit=1,
        max_scale_limit=10,
    )
    .add(
        "geo",
        colaboration_region,
        type_=ChartType.EFFECT_SCATTER,
        color="white"
    )
    .add(
        "geo",
        pair_colaboration_region,
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=3, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="Cooperation Network")
    )
    # .render("Cooperation_geo_scatter.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'world':'https://assets.pyecharts.org/assets/v5/maps/world'
#         }
#     });
# </script>
#
#         <div id="7b1c5c94a19b42d99b09d211b6fd5ac5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_7b1c5c94a19b42d99b09d211b6fd5ac5 = echarts.init(
#                     document.getElementById('7b1c5c94a19b42d99b09d211b6fd5ac5'), 'white', {renderer: 'canvas'});
#                 var option_7b1c5c94a19b42d99b09d211b6fd5ac5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "white",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "CN",
#                     "value": [
#                         116.4074,
#                         39.9042,
#                         97
#                     ]
#                 },
#                 {
#                     "name": "US",
#                     "value": [
#                         -100.445882,
#                         39.7837304,
#                         27
#                     ]
#                 },
#                 {
#                     "name": "HK",
#                     "value": [
#                         114.1849161,
#                         22.350627,
#                         7
#                     ]
#                 },
#                 {
#                     "name": "GB",
#                     "value": [
#                         -3.2765753,
#                         54.7023545,
#                         5
#                     ]
#                 },
#                 {
#                     "name": "SG",
#                     "value": [
#                         103.8194992,
#                         1.357107,
#                         4
#                     ]
#                 },
#                 {
#                     "name": "NL",
#                     "value": [
#                         4.7599085,
#                         52.3104607,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "MY",
#                     "value": [
#                         102.2656823,
#                         4.5693754,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "AT",
#                     "value": [
#                         14.12456,
#                         47.59397,
#                         3
#                     ]
#                 },
#                 {
#                     "name": "CA",
#                     "value": [
#                         -107.991707,
#                         61.0666922,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "PK",
#                     "value": [
#                         71.247499,
#                         30.3308401,
#                         2
#                     ]
#                 },
#                 {
#                     "name": "JP",
#                     "value": [
#                         139.2394179,
#                         36.5748441,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "BR",
#                     "value": [
#                         -40.4808697,
#                         -9.4690789,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "AU",
#                     "value": [
#                         134.755,
#                         -24.7761086,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "PT",
#                     "value": [
#                         -8.1353519,
#                         39.6621648,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "MO",
#                     "value": [
#                         10.935960870530739,
#                         44.5384728,
#                         1
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 3
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "HK->CN",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             116.4074,
#                             39.9042
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->US",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             -100.445882,
#                             39.7837304
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->HK",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             114.1849161,
#                             22.350627
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->GB",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             -3.2765753,
#                             54.7023545
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->SG",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             103.8194992,
#                             1.357107
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "HK->NL",
#                     "coords": [
#                         [
#                             114.1849161,
#                             22.350627
#                         ],
#                         [
#                             4.7599085,
#                             52.3104607
#                         ]
